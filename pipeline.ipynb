# %%
import os
import gc
import shutil
import time
import pandas as pd
import dask.dataframe as dd
from pathlib import Path
from datetime import datetime
from dask.diagnostics import ProgressBar
import uuid

# Your custom functions
from process_and_stream import preprocess_category, convert_to_dd, clean_data_dask

# Set paths
BASE_DIR = r"C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3"
RAW_DIR = os.path.join(BASE_DIR, "raw_files")
OUTPUT_DIR = os.path.join(BASE_DIR, "output_folder")
CLEANED_DIR = os.path.join(BASE_DIR, "cleaned_data")
SAMPLES_DIR = os.path.join(BASE_DIR, "samples")
STATS_DIR = os.path.join(BASE_DIR, "stats")

# Ensure dirs exist
for d in [CLEANED_DIR, SAMPLES_DIR, STATS_DIR]:
    os.makedirs(d, exist_ok=True)

# Categories to process
categories = [
    "Musical_Instruments"
]

def log(msg):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] {msg}")

def process_and_stream(category):
    review_tar = os.path.join(RAW_DIR, f"raw_review_{category}.tar.bz2")
    meta_tar = os.path.join(RAW_DIR, f"raw_meta_{category}.tar.bz2")

    try:
        log(f"🔄 Processing category: {category}")
        preprocess_category(review_tar, meta_tar, OUTPUT_DIR, category)

        review_df = convert_to_dd(os.path.join(OUTPUT_DIR, "reviews_parquet"), category)
        meta_df = convert_to_dd(os.path.join(OUTPUT_DIR, "meta_parquet"), category)

        if review_df is None or meta_df is None:
            log(f"⚠️ Skipped {category} due to missing review/meta")
            return

        cleaned = clean_data_dask(category, review_df, meta_df)

        start = time.time()
        cleaned = cleaned.repartition(npartitions=80)
        print(f"✅ Repartitioned in {time.time() - start:.2f} seconds")

        partition_dir = os.path.join(CLEANED_DIR, category)
        os.makedirs(partition_dir, exist_ok=True)

        # Clean out old files in the category folder
        for f in os.listdir(partition_dir):
            try:
                os.remove(os.path.join(partition_dir, f))
            except Exception as e:
                log(f"⚠️ Failed to delete old file {f}: {e}")

        # Write each partition as CSV
        with ProgressBar():
            for i in range(cleaned.npartitions):
                part = cleaned.get_partition(i)
                try:
                    part.to_csv(
                        os.path.join(partition_dir, f"part_{i}_*.csv"),
                        index=False, single_file=True
                    )
                    log(f"💾 Saved partition {i}")
                except Exception as e:          
                    log(f"⚠️ Failed to write partition {i} for {category}: {e}")

        log(f"✅ Done: {category}")

    except Exception as e:
        log(f"❌ ERROR in {category}: {str(e)}")

    finally:
        # Clean up temp dirs and memory
        for sub in ["reviews_parquet", "meta_parquet", "temp_extract"]:
            path = os.path.join(OUTPUT_DIR, sub)
            if os.path.exists(path):
                try:
                    shutil.rmtree(path)
                except Exception as e:
                    log(f"⚠️ Failed to delete {path}: {e}")
        gc.collect()

if __name__ == "__main__":
    for cat in categories:
        process_and_stream(cat)
# Out:
# [23:29:46] 🔄 Processing category: Musical_Instruments
# Extracting tar files for Musical_Instruments...
# Extracting C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3\raw_files\raw_review_Musical_Instruments.tar.bz2 to C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3\output_folder\temp_extract\Musical_Instruments
# Extracting C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3\raw_files\raw_meta_Musical_Instruments.tar.bz2 to C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3\output_folder\temp_extract\Musical_Instruments
# Found 5 Arrow files
# Saved batch 0 (1000 rows)
# Saved batch 1 (1000 rows)
# Saved batch 2 (1000 rows)
# Saved batch 3 (1000 rows)
# Saved batch 4 (1000 rows)
# Saved batch 5 (1000 rows)
# Saved batch 6 (1000 rows)
# Saved batch 7 (1000 rows)
# Saved batch 8 (1000 rows)
# Saved batch 9 (1000 rows)
# Saved batch 10 (1000 rows)
# Saved batch 11 (1000 rows)
# Saved batch 12 (1000 rows)
# Saved batch 13 (1000 rows)
# Saved batch 14 (1000 rows)
# Saved batch 15 (1000 rows)
# Saved batch 16 (1000 rows)
# Saved batch 17 (1000 rows)
# Saved batch 18 (1000 rows)
# Saved batch 19 (1000 rows)
# Saved batch 20 (1000 rows)
# Saved batch 21 (1000 rows)
# Saved batch 22 (1000 rows)
# Saved batch 23 (1000 rows)
# Saved batch 24 (1000 rows)
# Saved batch 25 (1000 rows)
# Saved batch 26 (1000 rows)
# Saved batch 27 (1000 rows)
# Saved batch 28 (1000 rows)
# Saved batch 29 (1000 rows)
# Saved batch 30 (1000 rows)
# Saved batch 31 (1000 rows)
# Saved batch 32 (1000 rows)
# Saved batch 33 (1000 rows)
# Saved batch 34 (1000 rows)
# Saved batch 35 (1000 rows)
# Saved batch 36 (1000 rows)
# Saved batch 37 (1000 rows)
# Saved batch 38 (1000 rows)
# Saved batch 39 (1000 rows)
# Saved batch 40 (1000 rows)
# Saved batch 41 (1000 rows)
# Saved batch 42 (1000 rows)
# Saved batch 43 (1000 rows)
# Saved batch 44 (1000 rows)
# Saved batch 45 (1000 rows)
# Saved batch 46 (1000 rows)
# Saved batch 47 (1000 rows)
# Saved batch 48 (1000 rows)
# Saved batch 49 (1000 rows)
# Saved batch 50 (1000 rows)
# Saved batch 51 (1000 rows)
# Saved batch 52 (1000 rows)
# Saved batch 53 (1000 rows)
# Saved batch 54 (1000 rows)
# Saved batch 55 (1000 rows)
# Saved batch 56 (1000 rows)
# Saved batch 57 (1000 rows)
# Saved batch 58 (1000 rows)
# Saved batch 59 (1000 rows)
# Saved batch 60 (1000 rows)
# Saved batch 61 (1000 rows)
# Saved batch 62 (1000 rows)
# Saved batch 63 (1000 rows)
# Saved batch 64 (1000 rows)
# Saved batch 65 (1000 rows)
# Saved batch 66 (1000 rows)
# Saved batch 67 (1000 rows)
# Saved batch 68 (1000 rows)
# Saved batch 69 (1000 rows)
# Saved batch 70 (1000 rows)
# Saved batch 71 (1000 rows)
# Saved batch 72 (1000 rows)
# Saved batch 73 (1000 rows)
# Saved batch 74 (1000 rows)
# Saved batch 75 (1000 rows)
# Saved batch 76 (1000 rows)
# Saved batch 77 (1000 rows)
# Saved batch 78 (1000 rows)
# Saved batch 79 (1000 rows)
# Saved batch 80 (1000 rows)
# Saved batch 81 (1000 rows)
# Saved batch 82 (1000 rows)
# Saved batch 83 (1000 rows)
# Saved batch 84 (1000 rows)
# Saved batch 85 (1000 rows)
# Saved batch 86 (1000 rows)
# Saved batch 87 (1000 rows)
# Saved batch 88 (1000 rows)
# Saved batch 89 (1000 rows)
# Saved batch 90 (1000 rows)
# Saved batch 91 (1000 rows)
# Saved batch 92 (1000 rows)
# Saved batch 93 (1000 rows)
# Saved batch 94 (1000 rows)
# Saved batch 95 (1000 rows)
# Saved batch 96 (1000 rows)
# Saved batch 97 (1000 rows)
# Saved batch 98 (1000 rows)
# Saved batch 99 (1000 rows)
# Saved batch 100 (1000 rows)
# Saved batch 101 (1000 rows)
# Saved batch 102 (1000 rows)
# Saved batch 103 (1000 rows)
# Saved batch 104 (1000 rows)
# Saved batch 105 (1000 rows)
# Saved final batch 106 (797 rows)
# Saved batch 106 (1000 rows)
# Saved batch 107 (1000 rows)
# Saved batch 108 (1000 rows)
# Saved batch 109 (1000 rows)
# Saved batch 110 (1000 rows)
# Saved batch 111 (1000 rows)
# Saved batch 112 (1000 rows)
# Saved batch 113 (1000 rows)
# Saved batch 114 (1000 rows)
# Saved batch 115 (1000 rows)
# Saved batch 116 (1000 rows)
# Saved batch 117 (1000 rows)
# Saved batch 118 (1000 rows)
# Saved batch 119 (1000 rows)
# Saved batch 120 (1000 rows)
# Saved batch 121 (1000 rows)
# Saved batch 122 (1000 rows)
# Saved batch 123 (1000 rows)
# Saved batch 124 (1000 rows)
# Saved batch 125 (1000 rows)
# Saved batch 126 (1000 rows)
# Saved batch 127 (1000 rows)
# Saved batch 128 (1000 rows)
# Saved batch 129 (1000 rows)
# Saved batch 130 (1000 rows)
# Saved batch 131 (1000 rows)
# Saved batch 132 (1000 rows)
# Saved batch 133 (1000 rows)
# Saved batch 134 (1000 rows)
# Saved batch 135 (1000 rows)
# Saved batch 136 (1000 rows)
# Saved batch 137 (1000 rows)
# Saved batch 138 (1000 rows)
# Saved batch 139 (1000 rows)
# Saved batch 140 (1000 rows)
# Saved batch 141 (1000 rows)
# Saved batch 142 (1000 rows)
# Saved batch 143 (1000 rows)
# Saved batch 144 (1000 rows)
# Saved batch 145 (1000 rows)
# Saved batch 146 (1000 rows)
# Saved batch 147 (1000 rows)
# Saved batch 148 (1000 rows)
# Saved batch 149 (1000 rows)
# Saved batch 150 (1000 rows)
# Saved batch 151 (1000 rows)
# Saved batch 152 (1000 rows)
# Saved batch 153 (1000 rows)
# Saved batch 154 (1000 rows)
# Saved batch 155 (1000 rows)
# Saved batch 156 (1000 rows)
# Saved batch 157 (1000 rows)
# Saved batch 158 (1000 rows)
# Saved batch 159 (1000 rows)
# Saved batch 160 (1000 rows)
# Saved batch 161 (1000 rows)
# Saved batch 162 (1000 rows)
# Saved batch 163 (1000 rows)
# Saved batch 164 (1000 rows)
# Saved batch 165 (1000 rows)
# Saved batch 166 (1000 rows)
# Saved batch 167 (1000 rows)
# Saved batch 168 (1000 rows)
# Saved batch 169 (1000 rows)
# Saved batch 170 (1000 rows)
# Saved batch 171 (1000 rows)
# Saved batch 172 (1000 rows)
# Saved batch 173 (1000 rows)
# Saved batch 174 (1000 rows)
# Saved batch 175 (1000 rows)
# Saved batch 176 (1000 rows)
# Saved batch 177 (1000 rows)
# Saved batch 178 (1000 rows)
# Saved batch 179 (1000 rows)
# Saved batch 180 (1000 rows)
# Saved batch 181 (1000 rows)
# Saved batch 182 (1000 rows)
# Saved batch 183 (1000 rows)
# Saved batch 184 (1000 rows)
# Saved batch 185 (1000 rows)
# Saved batch 186 (1000 rows)
# Saved batch 187 (1000 rows)
# Saved batch 188 (1000 rows)
# Saved batch 189 (1000 rows)
# Saved batch 190 (1000 rows)
# Saved batch 191 (1000 rows)
# Saved batch 192 (1000 rows)
# Saved batch 193 (1000 rows)
# Saved batch 194 (1000 rows)
# Saved batch 195 (1000 rows)
# Saved batch 196 (1000 rows)
# Saved batch 197 (1000 rows)
# Saved batch 198 (1000 rows)
# Saved batch 199 (1000 rows)
# Saved batch 200 (1000 rows)
# Saved batch 201 (1000 rows)
# Saved batch 202 (1000 rows)
# Saved batch 203 (1000 rows)
# Saved batch 204 (1000 rows)
# Saved batch 205 (1000 rows)
# Saved batch 206 (1000 rows)
# Saved batch 207 (1000 rows)
# Saved batch 208 (1000 rows)
# Saved batch 209 (1000 rows)
# Saved batch 210 (1000 rows)
# Saved batch 211 (1000 rows)
# Saved final batch 212 (796 rows)
# Saved batch 212 (1000 rows)
# Saved batch 213 (1000 rows)
# Saved batch 214 (1000 rows)
# Saved batch 215 (1000 rows)
# Saved batch 216 (1000 rows)
# Saved batch 217 (1000 rows)
# Saved batch 218 (1000 rows)
# Saved batch 219 (1000 rows)
# Saved batch 220 (1000 rows)
# Saved batch 221 (1000 rows)
# Saved batch 222 (1000 rows)
# Saved batch 223 (1000 rows)
# Saved batch 224 (1000 rows)
# Saved batch 225 (1000 rows)
# Saved batch 226 (1000 rows)
# Saved batch 227 (1000 rows)
# Saved batch 228 (1000 rows)
# Saved batch 229 (1000 rows)
# Saved batch 230 (1000 rows)
# Saved batch 231 (1000 rows)
# Saved batch 232 (1000 rows)
# Saved batch 233 (1000 rows)
# Saved batch 234 (1000 rows)
# Saved batch 235 (1000 rows)
# Saved batch 236 (1000 rows)
# Saved batch 237 (1000 rows)
# Saved batch 238 (1000 rows)
# Saved batch 239 (1000 rows)
# Saved batch 240 (1000 rows)
# Saved batch 241 (1000 rows)
# Saved batch 242 (1000 rows)
# Saved batch 243 (1000 rows)
# Saved batch 244 (1000 rows)
# Saved batch 245 (1000 rows)
# Saved batch 246 (1000 rows)
# Saved batch 247 (1000 rows)
# Saved batch 248 (1000 rows)
# Saved batch 249 (1000 rows)
# Saved batch 250 (1000 rows)
# Saved batch 251 (1000 rows)
# Saved batch 252 (1000 rows)
# Saved batch 253 (1000 rows)
# Saved batch 254 (1000 rows)
# Saved batch 255 (1000 rows)
# Saved batch 256 (1000 rows)
# Saved batch 257 (1000 rows)
# Saved batch 258 (1000 rows)
# Saved batch 259 (1000 rows)
# Saved batch 260 (1000 rows)
# Saved batch 261 (1000 rows)
# Saved batch 262 (1000 rows)
# Saved batch 263 (1000 rows)
# Saved batch 264 (1000 rows)
# Saved batch 265 (1000 rows)
# Saved batch 266 (1000 rows)
# Saved batch 267 (1000 rows)
# Saved batch 268 (1000 rows)
# Saved batch 269 (1000 rows)
# Saved batch 270 (1000 rows)
# Saved batch 271 (1000 rows)
# Saved batch 272 (1000 rows)
# Saved batch 273 (1000 rows)
# Saved batch 274 (1000 rows)
# Saved batch 275 (1000 rows)
# Saved batch 276 (1000 rows)
# Saved batch 277 (1000 rows)
# Saved batch 278 (1000 rows)
# Saved batch 279 (1000 rows)
# Saved batch 280 (1000 rows)
# Saved batch 281 (1000 rows)
# Saved batch 282 (1000 rows)
# Saved batch 283 (1000 rows)
# Saved batch 284 (1000 rows)
# Saved batch 285 (1000 rows)
# Saved batch 286 (1000 rows)
# Saved batch 287 (1000 rows)
# Saved batch 288 (1000 rows)
# Saved batch 289 (1000 rows)
# Saved batch 290 (1000 rows)
# Saved batch 291 (1000 rows)
# Saved batch 292 (1000 rows)
# Saved batch 293 (1000 rows)
# Saved batch 294 (1000 rows)
# Saved batch 295 (1000 rows)
# Saved batch 296 (1000 rows)
# Saved batch 297 (1000 rows)
# Saved batch 298 (1000 rows)
# Saved batch 299 (1000 rows)
# Saved batch 300 (1000 rows)
# Saved batch 301 (1000 rows)
# Saved batch 302 (1000 rows)
# Saved batch 303 (1000 rows)
# Saved batch 304 (1000 rows)
# Saved batch 305 (1000 rows)
# Saved batch 306 (1000 rows)
# Saved batch 307 (1000 rows)
# Saved batch 308 (1000 rows)
# Saved batch 309 (1000 rows)
# Saved batch 310 (1000 rows)
# Saved batch 311 (1000 rows)
# Saved batch 312 (1000 rows)
# Saved batch 313 (1000 rows)
# Saved batch 314 (1000 rows)
# Saved batch 315 (1000 rows)
# Saved batch 316 (1000 rows)
# Saved batch 317 (1000 rows)
# Saved batch 318 (1000 rows)
# Saved batch 319 (1000 rows)
# Saved batch 320 (1000 rows)
# Saved batch 321 (1000 rows)
# Saved batch 322 (1000 rows)
# Saved batch 323 (1000 rows)
# Saved batch 324 (1000 rows)
# Saved batch 325 (1000 rows)
# Saved batch 326 (1000 rows)
# Saved batch 327 (1000 rows)
# Saved batch 328 (1000 rows)
# Saved batch 329 (1000 rows)
# Saved batch 330 (1000 rows)
# Saved batch 331 (1000 rows)
# Saved batch 332 (1000 rows)
# Saved batch 333 (1000 rows)
# Saved batch 334 (1000 rows)
# Saved batch 335 (1000 rows)
# Saved batch 336 (1000 rows)
# Saved batch 337 (1000 rows)
# Saved batch 338 (1000 rows)
# Saved batch 339 (1000 rows)
# Saved batch 340 (1000 rows)
# Saved batch 341 (1000 rows)
# Saved batch 342 (1000 rows)
# Saved batch 343 (1000 rows)
# Saved batch 344 (1000 rows)
# Saved batch 345 (1000 rows)
# Saved batch 346 (1000 rows)
# Saved batch 347 (1000 rows)
# Saved batch 348 (1000 rows)
# Saved batch 349 (1000 rows)
# Saved batch 350 (1000 rows)
# Saved batch 351 (1000 rows)
# Saved batch 352 (1000 rows)
# Saved batch 353 (1000 rows)
# Saved batch 354 (1000 rows)
# Saved batch 355 (1000 rows)
# Saved batch 356 (1000 rows)
# Saved batch 357 (1000 rows)
# Saved batch 358 (1000 rows)
# Saved batch 359 (1000 rows)
# Saved batch 360 (1000 rows)
# Saved batch 361 (1000 rows)
# Saved batch 362 (1000 rows)
# Saved batch 363 (1000 rows)
# Saved batch 364 (1000 rows)
# Saved batch 365 (1000 rows)
# Saved batch 366 (1000 rows)
# Saved batch 367 (1000 rows)
# Saved batch 368 (1000 rows)
# Saved batch 369 (1000 rows)
# Saved batch 370 (1000 rows)
# Saved batch 371 (1000 rows)
# Saved batch 372 (1000 rows)
# Saved batch 373 (1000 rows)
# Saved batch 374 (1000 rows)
# Saved batch 375 (1000 rows)
# Saved batch 376 (1000 rows)
# Saved batch 377 (1000 rows)
# Saved batch 378 (1000 rows)
# Saved batch 379 (1000 rows)
# Saved batch 380 (1000 rows)
# Saved batch 381 (1000 rows)
# Saved batch 382 (1000 rows)
# Saved batch 383 (1000 rows)
# Saved batch 384 (1000 rows)
# Saved batch 385 (1000 rows)
# Saved batch 386 (1000 rows)
# Saved batch 387 (1000 rows)
# Saved batch 388 (1000 rows)
# Saved batch 389 (1000 rows)
# Saved batch 390 (1000 rows)
# Saved batch 391 (1000 rows)
# Saved batch 392 (1000 rows)
# Saved batch 393 (1000 rows)
# Saved batch 394 (1000 rows)
# Saved batch 395 (1000 rows)
# Saved batch 396 (1000 rows)
# Saved batch 397 (1000 rows)
# Saved batch 398 (1000 rows)
# Saved batch 399 (1000 rows)
# Saved batch 400 (1000 rows)
# Saved batch 401 (1000 rows)
# Saved batch 402 (1000 rows)
# Saved batch 403 (1000 rows)
# Saved batch 404 (1000 rows)
# Saved batch 405 (1000 rows)
# Saved batch 406 (1000 rows)
# Saved batch 407 (1000 rows)
# Saved batch 408 (1000 rows)
# Saved batch 409 (1000 rows)
# Saved batch 410 (1000 rows)
# Saved batch 411 (1000 rows)
# Saved batch 412 (1000 rows)
# Saved batch 413 (1000 rows)
# Saved batch 414 (1000 rows)
# Saved batch 415 (1000 rows)
# Saved batch 416 (1000 rows)
# Saved batch 417 (1000 rows)
# Saved batch 418 (1000 rows)
# Saved batch 419 (1000 rows)
# Saved batch 420 (1000 rows)
# Saved batch 421 (1000 rows)
# Saved batch 422 (1000 rows)
# Saved batch 423 (1000 rows)
# Saved batch 424 (1000 rows)
# Saved batch 425 (1000 rows)
# Saved batch 426 (1000 rows)
# Saved batch 427 (1000 rows)
# Saved batch 428 (1000 rows)
# Saved batch 429 (1000 rows)
# Saved batch 430 (1000 rows)
# Saved batch 431 (1000 rows)
# Saved batch 432 (1000 rows)
# Saved batch 433 (1000 rows)
# Saved batch 434 (1000 rows)
# Saved batch 435 (1000 rows)
# Saved batch 436 (1000 rows)
# Saved batch 437 (1000 rows)
# Saved batch 438 (1000 rows)
# Saved batch 439 (1000 rows)
# Saved batch 440 (1000 rows)
# Saved batch 441 (1000 rows)
# Saved batch 442 (1000 rows)
# Saved batch 443 (1000 rows)
# Saved batch 444 (1000 rows)
# Saved batch 445 (1000 rows)
# Saved batch 446 (1000 rows)
# Saved batch 447 (1000 rows)
# Saved batch 448 (1000 rows)
# Saved batch 449 (1000 rows)
# Saved batch 450 (1000 rows)
# Saved batch 451 (1000 rows)
# Saved batch 452 (1000 rows)
# Saved batch 453 (1000 rows)
# Saved batch 454 (1000 rows)
# Saved batch 455 (1000 rows)
# Saved batch 456 (1000 rows)
# Saved batch 457 (1000 rows)
# Saved batch 458 (1000 rows)
# Saved batch 459 (1000 rows)
# Saved batch 460 (1000 rows)
# Saved batch 461 (1000 rows)
# Saved batch 462 (1000 rows)
# Saved batch 463 (1000 rows)
# Saved batch 464 (1000 rows)
# Saved batch 465 (1000 rows)
# Saved batch 466 (1000 rows)
# Saved batch 467 (1000 rows)
# Saved batch 468 (1000 rows)
# Saved batch 469 (1000 rows)
# Saved batch 470 (1000 rows)
# Saved batch 471 (1000 rows)
# Saved batch 472 (1000 rows)
# Saved batch 473 (1000 rows)
# Saved batch 474 (1000 rows)
# Saved batch 475 (1000 rows)
# Saved batch 476 (1000 rows)
# Saved batch 477 (1000 rows)
# Saved batch 478 (1000 rows)
# Saved batch 479 (1000 rows)
# Saved batch 480 (1000 rows)
# Saved batch 481 (1000 rows)
# Saved batch 482 (1000 rows)
# Saved batch 483 (1000 rows)
# Saved batch 484 (1000 rows)
# Saved batch 485 (1000 rows)
# Saved batch 486 (1000 rows)
# Saved batch 487 (1000 rows)
# Saved batch 488 (1000 rows)
# Saved batch 489 (1000 rows)
# Saved batch 490 (1000 rows)
# Saved batch 491 (1000 rows)
# Saved batch 492 (1000 rows)
# Saved batch 493 (1000 rows)
# Saved batch 494 (1000 rows)
# Saved batch 495 (1000 rows)
# Saved batch 496 (1000 rows)
# Saved batch 497 (1000 rows)
# Saved batch 498 (1000 rows)
# Saved batch 499 (1000 rows)
# Saved batch 500 (1000 rows)
# Saved batch 501 (1000 rows)
# Saved batch 502 (1000 rows)
# Saved batch 503 (1000 rows)
# Saved batch 504 (1000 rows)
# Saved batch 505 (1000 rows)
# Saved batch 506 (1000 rows)
# Saved batch 507 (1000 rows)
# Saved batch 508 (1000 rows)
# Saved batch 509 (1000 rows)
# Saved batch 510 (1000 rows)
# Saved batch 511 (1000 rows)
# Saved batch 512 (1000 rows)
# Saved batch 513 (1000 rows)
# Saved batch 514 (1000 rows)
# Saved batch 515 (1000 rows)
# Saved batch 516 (1000 rows)
# Saved batch 517 (1000 rows)
# Saved batch 518 (1000 rows)
# Saved batch 519 (1000 rows)
# Saved batch 520 (1000 rows)
# Saved batch 521 (1000 rows)
# Saved batch 522 (1000 rows)
# Saved batch 523 (1000 rows)
# Saved batch 524 (1000 rows)
# Saved batch 525 (1000 rows)
# Saved batch 526 (1000 rows)
# Saved batch 527 (1000 rows)
# Saved batch 528 (1000 rows)
# Saved batch 529 (1000 rows)
# Saved batch 530 (1000 rows)
# Saved batch 531 (1000 rows)
# Saved batch 532 (1000 rows)
# Saved batch 533 (1000 rows)
# Saved batch 534 (1000 rows)
# Saved batch 535 (1000 rows)
# Saved batch 536 (1000 rows)
# Saved batch 537 (1000 rows)
# Saved batch 538 (1000 rows)
# Saved batch 539 (1000 rows)
# Saved batch 540 (1000 rows)
# Saved batch 541 (1000 rows)
# Saved batch 542 (1000 rows)
# Saved batch 543 (1000 rows)
# Saved batch 544 (1000 rows)
# Saved batch 545 (1000 rows)
# Saved batch 546 (1000 rows)
# Saved batch 547 (1000 rows)
# Saved batch 548 (1000 rows)
# Saved batch 549 (1000 rows)
# Saved batch 550 (1000 rows)
# Saved batch 551 (1000 rows)
# Saved batch 552 (1000 rows)
# Saved batch 553 (1000 rows)
# Saved batch 554 (1000 rows)
# Saved batch 555 (1000 rows)
# Saved batch 556 (1000 rows)
# Saved batch 557 (1000 rows)
# Saved batch 558 (1000 rows)
# Saved batch 559 (1000 rows)
# Saved batch 560 (1000 rows)
# Saved batch 561 (1000 rows)
# Saved batch 562 (1000 rows)
# Saved batch 563 (1000 rows)
# Saved batch 564 (1000 rows)
# Saved batch 565 (1000 rows)
# Saved batch 566 (1000 rows)
# Saved batch 567 (1000 rows)
# Saved batch 568 (1000 rows)
# Saved batch 569 (1000 rows)
# Saved batch 570 (1000 rows)
# Saved batch 571 (1000 rows)
# Saved batch 572 (1000 rows)
# Saved batch 573 (1000 rows)
# Saved batch 574 (1000 rows)
# Saved batch 575 (1000 rows)
# Saved batch 576 (1000 rows)
# Saved batch 577 (1000 rows)
# Saved batch 578 (1000 rows)
# Saved batch 579 (1000 rows)
# Saved batch 580 (1000 rows)
# Saved batch 581 (1000 rows)
# Saved batch 582 (1000 rows)
# Saved batch 583 (1000 rows)
# Saved batch 584 (1000 rows)
# Saved batch 585 (1000 rows)
# Saved batch 586 (1000 rows)
# Saved batch 587 (1000 rows)
# Saved batch 588 (1000 rows)
# Saved batch 589 (1000 rows)
# Saved batch 590 (1000 rows)
# Saved batch 591 (1000 rows)
# Saved batch 592 (1000 rows)
# Saved batch 593 (1000 rows)
# Saved batch 594 (1000 rows)
# Saved batch 595 (1000 rows)
# Saved batch 596 (1000 rows)
# Saved batch 597 (1000 rows)
# Saved batch 598 (1000 rows)
# Saved batch 599 (1000 rows)
# Saved batch 600 (1000 rows)
# Saved batch 601 (1000 rows)
# Saved batch 602 (1000 rows)
# Saved batch 603 (1000 rows)
# Saved batch 604 (1000 rows)
# Saved batch 605 (1000 rows)
# Saved batch 606 (1000 rows)
# Saved batch 607 (1000 rows)
# Saved batch 608 (1000 rows)
# Saved batch 609 (1000 rows)
# Saved batch 610 (1000 rows)
# Saved batch 611 (1000 rows)
# Saved batch 612 (1000 rows)
# Saved batch 613 (1000 rows)
# Saved batch 614 (1000 rows)
# Saved batch 615 (1000 rows)
# Saved batch 616 (1000 rows)
# Saved batch 617 (1000 rows)
# Saved batch 618 (1000 rows)
# Saved batch 619 (1000 rows)
# Saved batch 620 (1000 rows)
# Saved batch 621 (1000 rows)
# Saved batch 622 (1000 rows)
# Saved batch 623 (1000 rows)
# Saved batch 624 (1000 rows)
# Saved batch 625 (1000 rows)
# Saved batch 626 (1000 rows)
# Saved batch 627 (1000 rows)
# Saved batch 628 (1000 rows)
# Saved batch 629 (1000 rows)
# Saved batch 630 (1000 rows)
# Saved batch 631 (1000 rows)
# Saved batch 632 (1000 rows)
# Saved batch 633 (1000 rows)
# Saved batch 634 (1000 rows)
# Saved batch 635 (1000 rows)
# Saved batch 636 (1000 rows)
# Saved batch 637 (1000 rows)
# Saved batch 638 (1000 rows)
# Saved batch 639 (1000 rows)
# Saved batch 640 (1000 rows)
# Saved batch 641 (1000 rows)
# Saved batch 642 (1000 rows)
# Saved batch 643 (1000 rows)
# Saved batch 644 (1000 rows)
# Saved batch 645 (1000 rows)
# Saved batch 646 (1000 rows)
# Saved batch 647 (1000 rows)
# Saved batch 648 (1000 rows)
# Saved batch 649 (1000 rows)
# Saved batch 650 (1000 rows)
# Saved batch 651 (1000 rows)
# Saved batch 652 (1000 rows)
# Saved batch 653 (1000 rows)
# Saved batch 654 (1000 rows)
# Saved batch 655 (1000 rows)
# Saved batch 656 (1000 rows)
# Saved batch 657 (1000 rows)
# Saved batch 658 (1000 rows)
# Saved batch 659 (1000 rows)
# Saved batch 660 (1000 rows)
# Saved batch 661 (1000 rows)
# Saved batch 662 (1000 rows)
# Saved batch 663 (1000 rows)
# Saved batch 664 (1000 rows)
# Saved batch 665 (1000 rows)
# Saved batch 666 (1000 rows)
# Saved batch 667 (1000 rows)
# Saved batch 668 (1000 rows)
# Saved batch 669 (1000 rows)
# Saved batch 670 (1000 rows)
# Saved batch 671 (1000 rows)
# Saved batch 672 (1000 rows)
# Saved batch 673 (1000 rows)
# Saved batch 674 (1000 rows)
# Saved batch 675 (1000 rows)
# Saved batch 676 (1000 rows)
# Saved batch 677 (1000 rows)
# Saved batch 678 (1000 rows)
# Saved batch 679 (1000 rows)
# Saved batch 680 (1000 rows)
# Saved batch 681 (1000 rows)
# Saved batch 682 (1000 rows)
# Saved batch 683 (1000 rows)
# Saved batch 684 (1000 rows)
# Saved batch 685 (1000 rows)
# Saved batch 686 (1000 rows)
# Saved batch 687 (1000 rows)
# Saved batch 688 (1000 rows)
# Saved batch 689 (1000 rows)
# Saved batch 690 (1000 rows)
# Saved batch 691 (1000 rows)
# Saved batch 692 (1000 rows)
# Saved batch 693 (1000 rows)
# Saved batch 694 (1000 rows)
# Saved batch 695 (1000 rows)
# Saved batch 696 (1000 rows)
# Saved batch 697 (1000 rows)
# Saved batch 698 (1000 rows)
# Saved batch 699 (1000 rows)
# Saved batch 700 (1000 rows)
# Saved batch 701 (1000 rows)
# Saved batch 702 (1000 rows)
# Saved batch 703 (1000 rows)
# Saved batch 704 (1000 rows)
# Saved batch 705 (1000 rows)
# Saved batch 706 (1000 rows)
# Saved batch 707 (1000 rows)
# Saved batch 708 (1000 rows)
# Saved batch 709 (1000 rows)
# Saved batch 710 (1000 rows)
# Saved batch 711 (1000 rows)
# Saved batch 712 (1000 rows)
# Saved batch 713 (1000 rows)
# Saved batch 714 (1000 rows)
# Saved batch 715 (1000 rows)
# Saved batch 716 (1000 rows)
# Saved batch 717 (1000 rows)
# Saved batch 718 (1000 rows)
# Saved batch 719 (1000 rows)
# Saved batch 720 (1000 rows)
# Saved batch 721 (1000 rows)
# Saved batch 722 (1000 rows)
# Saved batch 723 (1000 rows)
# Saved batch 724 (1000 rows)
# Saved batch 725 (1000 rows)
# Saved batch 726 (1000 rows)
# Saved batch 727 (1000 rows)
# Saved batch 728 (1000 rows)
# Saved batch 729 (1000 rows)
# Saved batch 730 (1000 rows)
# Saved batch 731 (1000 rows)
# Saved batch 732 (1000 rows)
# Saved batch 733 (1000 rows)
# Saved batch 734 (1000 rows)
# Saved batch 735 (1000 rows)
# Saved batch 736 (1000 rows)
# Saved batch 737 (1000 rows)
# Saved batch 738 (1000 rows)
# Saved batch 739 (1000 rows)
# Saved batch 740 (1000 rows)
# Saved batch 741 (1000 rows)
# Saved batch 742 (1000 rows)
# Saved batch 743 (1000 rows)
# Saved batch 744 (1000 rows)
# Saved batch 745 (1000 rows)
# Saved batch 746 (1000 rows)
# Saved batch 747 (1000 rows)
# Saved batch 748 (1000 rows)
# Saved batch 749 (1000 rows)
# Saved batch 750 (1000 rows)
# Saved batch 751 (1000 rows)
# Saved batch 752 (1000 rows)
# Saved batch 753 (1000 rows)
# Saved batch 754 (1000 rows)
# Saved batch 755 (1000 rows)
# Saved batch 756 (1000 rows)
# Saved batch 757 (1000 rows)
# Saved batch 758 (1000 rows)
# Saved batch 759 (1000 rows)
# Saved batch 760 (1000 rows)
# Saved batch 761 (1000 rows)
# Saved batch 762 (1000 rows)
# Saved batch 763 (1000 rows)
# Saved batch 764 (1000 rows)
# Saved batch 765 (1000 rows)
# Saved batch 766 (1000 rows)
# Saved batch 767 (1000 rows)
# Saved batch 768 (1000 rows)
# Saved batch 769 (1000 rows)
# Saved batch 770 (1000 rows)
# Saved batch 771 (1000 rows)
# Saved batch 772 (1000 rows)
# Saved batch 773 (1000 rows)
# Saved batch 774 (1000 rows)
# Saved batch 775 (1000 rows)
# Saved batch 776 (1000 rows)
# Saved batch 777 (1000 rows)
# Saved batch 778 (1000 rows)
# Saved batch 779 (1000 rows)
# Saved batch 780 (1000 rows)
# Saved batch 781 (1000 rows)
# Saved batch 782 (1000 rows)
# Saved batch 783 (1000 rows)
# Saved batch 784 (1000 rows)
# Saved batch 785 (1000 rows)
# Saved batch 786 (1000 rows)
# Saved batch 787 (1000 rows)
# Saved batch 788 (1000 rows)
# Saved batch 789 (1000 rows)
# Saved batch 790 (1000 rows)
# Saved batch 791 (1000 rows)
# Saved batch 792 (1000 rows)
# Saved batch 793 (1000 rows)
# Saved batch 794 (1000 rows)
# Saved batch 795 (1000 rows)
# Saved batch 796 (1000 rows)
# Saved batch 797 (1000 rows)
# Saved batch 798 (1000 rows)
# Saved batch 799 (1000 rows)
# Saved batch 800 (1000 rows)
# Saved batch 801 (1000 rows)
# Saved batch 802 (1000 rows)
# Saved batch 803 (1000 rows)
# Saved batch 804 (1000 rows)
# Saved batch 805 (1000 rows)
# Saved batch 806 (1000 rows)
# Saved batch 807 (1000 rows)
# Saved batch 808 (1000 rows)
# Saved batch 809 (1000 rows)
# Saved batch 810 (1000 rows)
# Saved batch 811 (1000 rows)
# Saved batch 812 (1000 rows)
# Saved batch 813 (1000 rows)
# Saved batch 814 (1000 rows)
# Saved batch 815 (1000 rows)
# Saved batch 816 (1000 rows)
# Saved batch 817 (1000 rows)
# Saved batch 818 (1000 rows)
# Saved batch 819 (1000 rows)
# Saved batch 820 (1000 rows)
# Saved batch 821 (1000 rows)
# Saved batch 822 (1000 rows)
# Saved batch 823 (1000 rows)
# Saved batch 824 (1000 rows)
# Saved batch 825 (1000 rows)
# Saved batch 826 (1000 rows)
# Saved batch 827 (1000 rows)
# Saved batch 828 (1000 rows)
# Saved batch 829 (1000 rows)
# Saved batch 830 (1000 rows)
# Saved batch 831 (1000 rows)
# Saved batch 832 (1000 rows)
# Saved batch 833 (1000 rows)
# Saved batch 834 (1000 rows)
# Saved batch 835 (1000 rows)
# Saved batch 836 (1000 rows)
# Saved batch 837 (1000 rows)
# Saved batch 838 (1000 rows)
# Saved batch 839 (1000 rows)
# Saved batch 840 (1000 rows)
# Saved batch 841 (1000 rows)
# Saved batch 842 (1000 rows)
# Saved batch 843 (1000 rows)
# Saved batch 844 (1000 rows)
# Saved batch 845 (1000 rows)
# Saved batch 846 (1000 rows)
# Saved batch 847 (1000 rows)
# Saved batch 848 (1000 rows)
# Saved batch 849 (1000 rows)
# Saved batch 850 (1000 rows)
# Saved batch 851 (1000 rows)
# Saved batch 852 (1000 rows)
# Saved batch 853 (1000 rows)
# Saved batch 854 (1000 rows)
# Saved batch 855 (1000 rows)
# Saved batch 856 (1000 rows)
# Saved batch 857 (1000 rows)
# Saved batch 858 (1000 rows)
# Saved batch 859 (1000 rows)
# Saved batch 860 (1000 rows)
# Saved batch 861 (1000 rows)
# Saved batch 862 (1000 rows)
# Saved batch 863 (1000 rows)
# Saved batch 864 (1000 rows)
# Saved batch 865 (1000 rows)
# Saved batch 866 (1000 rows)
# Saved batch 867 (1000 rows)
# Saved batch 868 (1000 rows)
# Saved batch 869 (1000 rows)
# Saved batch 870 (1000 rows)
# Saved batch 871 (1000 rows)
# Saved batch 872 (1000 rows)
# Saved batch 873 (1000 rows)
# Saved batch 874 (1000 rows)
# Saved batch 875 (1000 rows)
# Saved batch 876 (1000 rows)
# Saved batch 877 (1000 rows)
# Saved batch 878 (1000 rows)
# Saved batch 879 (1000 rows)
# Saved batch 880 (1000 rows)
# Saved batch 881 (1000 rows)
# Saved batch 882 (1000 rows)
# Saved batch 883 (1000 rows)
# Saved batch 884 (1000 rows)
# Saved batch 885 (1000 rows)
# Saved batch 886 (1000 rows)
# Saved batch 887 (1000 rows)
# Saved batch 888 (1000 rows)
# Saved batch 889 (1000 rows)
# Saved batch 890 (1000 rows)
# Saved batch 891 (1000 rows)
# Saved batch 892 (1000 rows)
# Saved batch 893 (1000 rows)
# Saved batch 894 (1000 rows)
# Saved batch 895 (1000 rows)
# Saved batch 896 (1000 rows)
# Saved batch 897 (1000 rows)
# Saved batch 898 (1000 rows)
# Saved batch 899 (1000 rows)
# Saved batch 900 (1000 rows)
# Saved batch 901 (1000 rows)
# Saved batch 902 (1000 rows)
# Saved batch 903 (1000 rows)
# Saved batch 904 (1000 rows)
# Saved batch 905 (1000 rows)
# Saved batch 906 (1000 rows)
# Saved batch 907 (1000 rows)
# Saved batch 908 (1000 rows)
# Saved batch 909 (1000 rows)
# Saved batch 910 (1000 rows)
# Saved batch 911 (1000 rows)
# Saved batch 912 (1000 rows)
# Saved batch 913 (1000 rows)
# Saved batch 914 (1000 rows)
# Saved batch 915 (1000 rows)
# Saved batch 916 (1000 rows)
# Saved batch 917 (1000 rows)
# Saved batch 918 (1000 rows)
# Saved batch 919 (1000 rows)
# Saved batch 920 (1000 rows)
# Saved batch 921 (1000 rows)
# Saved batch 922 (1000 rows)
# Saved batch 923 (1000 rows)
# Saved batch 924 (1000 rows)
# Saved batch 925 (1000 rows)
# Saved batch 926 (1000 rows)
# Saved batch 927 (1000 rows)
# Saved batch 928 (1000 rows)
# Saved batch 929 (1000 rows)
# Saved batch 930 (1000 rows)
# Saved batch 931 (1000 rows)
# Saved batch 932 (1000 rows)
# Saved batch 933 (1000 rows)
# Saved batch 934 (1000 rows)
# Saved batch 935 (1000 rows)
# Saved batch 936 (1000 rows)
# Saved batch 937 (1000 rows)
# Saved batch 938 (1000 rows)
# Saved batch 939 (1000 rows)
# Saved batch 940 (1000 rows)
# Saved batch 941 (1000 rows)
# Saved batch 942 (1000 rows)
# Saved batch 943 (1000 rows)
# Saved batch 944 (1000 rows)
# Saved batch 945 (1000 rows)
# Saved batch 946 (1000 rows)
# Saved batch 947 (1000 rows)
# Saved batch 948 (1000 rows)
# Saved batch 949 (1000 rows)
# Saved batch 950 (1000 rows)
# Saved batch 951 (1000 rows)
# Saved batch 952 (1000 rows)
# Saved batch 953 (1000 rows)
# Saved batch 954 (1000 rows)
# Saved batch 955 (1000 rows)
# Saved batch 956 (1000 rows)
# Saved batch 957 (1000 rows)
# Saved batch 958 (1000 rows)
# Saved batch 959 (1000 rows)
# Saved batch 960 (1000 rows)
# Saved batch 961 (1000 rows)
# Saved batch 962 (1000 rows)
# Saved batch 963 (1000 rows)
# Saved batch 964 (1000 rows)
# Saved batch 965 (1000 rows)
# Saved batch 966 (1000 rows)
# Saved batch 967 (1000 rows)
# Saved batch 968 (1000 rows)
# Saved batch 969 (1000 rows)
# Saved batch 970 (1000 rows)
# Saved batch 971 (1000 rows)
# Saved batch 972 (1000 rows)
# Saved batch 973 (1000 rows)
# Saved batch 974 (1000 rows)
# Saved batch 975 (1000 rows)
# Saved batch 976 (1000 rows)
# Saved batch 977 (1000 rows)
# Saved batch 978 (1000 rows)
# Saved batch 979 (1000 rows)
# Saved batch 980 (1000 rows)
# Saved batch 981 (1000 rows)
# Saved batch 982 (1000 rows)
# Saved batch 983 (1000 rows)
# Saved batch 984 (1000 rows)
# Saved batch 985 (1000 rows)
# Saved batch 986 (1000 rows)
# Saved batch 987 (1000 rows)
# Saved batch 988 (1000 rows)
# Saved batch 989 (1000 rows)
# Saved batch 990 (1000 rows)
# Saved batch 991 (1000 rows)
# Saved batch 992 (1000 rows)
# Saved batch 993 (1000 rows)
# Saved batch 994 (1000 rows)
# Saved batch 995 (1000 rows)
# Saved batch 996 (1000 rows)
# Saved batch 997 (1000 rows)
# Saved batch 998 (1000 rows)
# Saved batch 999 (1000 rows)
# Saved batch 1000 (1000 rows)
# Saved batch 1001 (1000 rows)
# Saved batch 1002 (1000 rows)
# Saved batch 1003 (1000 rows)
# Saved batch 1004 (1000 rows)
# Saved batch 1005 (1000 rows)
# Saved batch 1006 (1000 rows)
# Saved batch 1007 (1000 rows)
# Saved batch 1008 (1000 rows)
# Saved batch 1009 (1000 rows)
# Saved batch 1010 (1000 rows)
# Saved batch 1011 (1000 rows)
# Saved batch 1012 (1000 rows)
# Saved batch 1013 (1000 rows)
# Saved batch 1014 (1000 rows)
# Saved batch 1015 (1000 rows)
# Saved batch 1016 (1000 rows)
# Saved batch 1017 (1000 rows)
# Saved batch 1018 (1000 rows)
# Saved batch 1019 (1000 rows)
# Saved batch 1020 (1000 rows)
# Saved batch 1021 (1000 rows)
# Saved batch 1022 (1000 rows)
# Saved batch 1023 (1000 rows)
# Saved batch 1024 (1000 rows)
# Saved batch 1025 (1000 rows)
# Saved batch 1026 (1000 rows)
# Saved batch 1027 (1000 rows)
# Saved batch 1028 (1000 rows)
# Saved batch 1029 (1000 rows)
# Saved batch 1030 (1000 rows)
# Saved batch 1031 (1000 rows)
# Saved batch 1032 (1000 rows)
# Saved batch 1033 (1000 rows)
# Saved batch 1034 (1000 rows)
# Saved batch 1035 (1000 rows)
# Saved batch 1036 (1000 rows)
# Saved batch 1037 (1000 rows)
# Saved batch 1038 (1000 rows)
# Saved batch 1039 (1000 rows)
# Saved batch 1040 (1000 rows)
# Saved batch 1041 (1000 rows)
# Saved batch 1042 (1000 rows)
# Saved batch 1043 (1000 rows)
# Saved batch 1044 (1000 rows)
# Saved batch 1045 (1000 rows)
# Saved batch 1046 (1000 rows)
# Saved batch 1047 (1000 rows)
# Saved batch 1048 (1000 rows)
# Saved batch 1049 (1000 rows)
# Saved batch 1050 (1000 rows)
# Saved batch 1051 (1000 rows)
# Saved batch 1052 (1000 rows)
# Saved batch 1053 (1000 rows)
# Saved batch 1054 (1000 rows)
# Saved batch 1055 (1000 rows)
# Saved batch 1056 (1000 rows)
# Saved batch 1057 (1000 rows)
# Saved batch 1058 (1000 rows)
# Saved batch 1059 (1000 rows)
# Saved batch 1060 (1000 rows)
# Saved batch 1061 (1000 rows)
# Saved batch 1062 (1000 rows)
# Saved batch 1063 (1000 rows)
# Saved batch 1064 (1000 rows)
# Saved batch 1065 (1000 rows)
# Saved batch 1066 (1000 rows)
# Saved batch 1067 (1000 rows)
# Saved batch 1068 (1000 rows)
# Saved batch 1069 (1000 rows)
# Saved batch 1070 (1000 rows)
# Saved batch 1071 (1000 rows)
# Saved batch 1072 (1000 rows)
# Saved batch 1073 (1000 rows)
# Saved batch 1074 (1000 rows)
# Saved batch 1075 (1000 rows)
# Saved batch 1076 (1000 rows)
# Saved batch 1077 (1000 rows)
# Saved batch 1078 (1000 rows)
# Saved batch 1079 (1000 rows)
# Saved batch 1080 (1000 rows)
# Saved batch 1081 (1000 rows)
# Saved batch 1082 (1000 rows)
# Saved batch 1083 (1000 rows)
# Saved batch 1084 (1000 rows)
# Saved batch 1085 (1000 rows)
# Saved batch 1086 (1000 rows)
# Saved batch 1087 (1000 rows)
# Saved batch 1088 (1000 rows)
# Saved batch 1089 (1000 rows)
# Saved batch 1090 (1000 rows)
# Saved batch 1091 (1000 rows)
# Saved batch 1092 (1000 rows)
# Saved batch 1093 (1000 rows)
# Saved batch 1094 (1000 rows)
# Saved batch 1095 (1000 rows)
# Saved batch 1096 (1000 rows)
# Saved batch 1097 (1000 rows)
# Saved batch 1098 (1000 rows)
# Saved batch 1099 (1000 rows)
# Saved batch 1100 (1000 rows)
# Saved batch 1101 (1000 rows)
# Saved batch 1102 (1000 rows)
# Saved batch 1103 (1000 rows)
# Saved batch 1104 (1000 rows)
# Saved batch 1105 (1000 rows)
# Saved batch 1106 (1000 rows)
# Saved batch 1107 (1000 rows)
# Saved batch 1108 (1000 rows)
# Saved batch 1109 (1000 rows)
# Saved batch 1110 (1000 rows)
# Saved batch 1111 (1000 rows)
# Saved batch 1112 (1000 rows)
# Saved batch 1113 (1000 rows)
# Saved batch 1114 (1000 rows)
# Saved batch 1115 (1000 rows)
# Saved batch 1116 (1000 rows)
# Saved batch 1117 (1000 rows)
# Saved batch 1118 (1000 rows)
# Saved batch 1119 (1000 rows)
# Saved batch 1120 (1000 rows)
# Saved batch 1121 (1000 rows)
# Saved batch 1122 (1000 rows)
# Saved batch 1123 (1000 rows)
# Saved batch 1124 (1000 rows)
# Saved batch 1125 (1000 rows)
# Saved batch 1126 (1000 rows)
# Saved batch 1127 (1000 rows)
# Saved batch 1128 (1000 rows)
# Saved batch 1129 (1000 rows)
# Saved batch 1130 (1000 rows)
# Saved batch 1131 (1000 rows)
# Saved batch 1132 (1000 rows)
# Saved batch 1133 (1000 rows)
# Saved batch 1134 (1000 rows)
# Saved batch 1135 (1000 rows)
# Saved batch 1136 (1000 rows)
# Saved batch 1137 (1000 rows)
# Saved batch 1138 (1000 rows)
# Saved batch 1139 (1000 rows)
# Saved batch 1140 (1000 rows)
# Saved batch 1141 (1000 rows)
# Saved batch 1142 (1000 rows)
# Saved batch 1143 (1000 rows)
# Saved batch 1144 (1000 rows)
# Saved batch 1145 (1000 rows)
# Saved batch 1146 (1000 rows)
# Saved batch 1147 (1000 rows)
# Saved batch 1148 (1000 rows)
# Saved batch 1149 (1000 rows)
# Saved batch 1150 (1000 rows)
# Saved batch 1151 (1000 rows)
# Saved batch 1152 (1000 rows)
# Saved batch 1153 (1000 rows)
# Saved batch 1154 (1000 rows)
# Saved batch 1155 (1000 rows)
# Saved batch 1156 (1000 rows)
# Saved batch 1157 (1000 rows)
# Saved batch 1158 (1000 rows)
# Saved batch 1159 (1000 rows)
# Saved batch 1160 (1000 rows)
# Saved batch 1161 (1000 rows)
# Saved batch 1162 (1000 rows)
# Saved batch 1163 (1000 rows)
# Saved batch 1164 (1000 rows)
# Saved batch 1165 (1000 rows)
# Saved batch 1166 (1000 rows)
# Saved batch 1167 (1000 rows)
# Saved batch 1168 (1000 rows)
# Saved batch 1169 (1000 rows)
# Saved batch 1170 (1000 rows)
# Saved batch 1171 (1000 rows)
# Saved batch 1172 (1000 rows)
# Saved batch 1173 (1000 rows)
# Saved batch 1174 (1000 rows)
# Saved batch 1175 (1000 rows)
# Saved batch 1176 (1000 rows)
# Saved batch 1177 (1000 rows)
# Saved batch 1178 (1000 rows)
# Saved batch 1179 (1000 rows)
# Saved batch 1180 (1000 rows)
# Saved batch 1181 (1000 rows)
# Saved batch 1182 (1000 rows)
# Saved batch 1183 (1000 rows)
# Saved batch 1184 (1000 rows)
# Saved batch 1185 (1000 rows)
# Saved batch 1186 (1000 rows)
# Saved batch 1187 (1000 rows)
# Saved batch 1188 (1000 rows)
# Saved batch 1189 (1000 rows)
# Saved batch 1190 (1000 rows)
# Saved batch 1191 (1000 rows)
# Saved batch 1192 (1000 rows)
# Saved batch 1193 (1000 rows)
# Saved batch 1194 (1000 rows)
# Saved batch 1195 (1000 rows)
# Saved batch 1196 (1000 rows)
# Saved batch 1197 (1000 rows)
# Saved batch 1198 (1000 rows)
# Saved batch 1199 (1000 rows)
# Saved batch 1200 (1000 rows)
# Saved batch 1201 (1000 rows)
# Saved batch 1202 (1000 rows)
# Saved batch 1203 (1000 rows)
# Saved batch 1204 (1000 rows)
# Saved batch 1205 (1000 rows)
# Saved batch 1206 (1000 rows)
# Saved batch 1207 (1000 rows)
# Saved batch 1208 (1000 rows)
# Saved batch 1209 (1000 rows)
# Saved batch 1210 (1000 rows)
# Saved batch 1211 (1000 rows)
# Saved batch 1212 (1000 rows)
# Saved final batch 1213 (715 rows)
# Saved batch 1213 (1000 rows)
# Saved batch 1214 (1000 rows)
# Saved batch 1215 (1000 rows)
# Saved batch 1216 (1000 rows)
# Saved batch 1217 (1000 rows)
# Saved batch 1218 (1000 rows)
# Saved batch 1219 (1000 rows)
# Saved batch 1220 (1000 rows)
# Saved batch 1221 (1000 rows)
# Saved batch 1222 (1000 rows)
# Saved batch 1223 (1000 rows)
# Saved batch 1224 (1000 rows)
# Saved batch 1225 (1000 rows)
# Saved batch 1226 (1000 rows)
# Saved batch 1227 (1000 rows)
# Saved batch 1228 (1000 rows)
# Saved batch 1229 (1000 rows)
# Saved batch 1230 (1000 rows)
# Saved batch 1231 (1000 rows)
# Saved batch 1232 (1000 rows)
# Saved batch 1233 (1000 rows)
# Saved batch 1234 (1000 rows)
# Saved batch 1235 (1000 rows)
# Saved batch 1236 (1000 rows)
# Saved batch 1237 (1000 rows)
# Saved batch 1238 (1000 rows)
# Saved batch 1239 (1000 rows)
# Saved batch 1240 (1000 rows)
# Saved batch 1241 (1000 rows)
# Saved batch 1242 (1000 rows)
# Saved batch 1243 (1000 rows)
# Saved batch 1244 (1000 rows)
# Saved batch 1245 (1000 rows)
# Saved batch 1246 (1000 rows)
# Saved batch 1247 (1000 rows)
# Saved batch 1248 (1000 rows)
# Saved batch 1249 (1000 rows)
# Saved batch 1250 (1000 rows)
# Saved batch 1251 (1000 rows)
# Saved batch 1252 (1000 rows)
# Saved batch 1253 (1000 rows)
# Saved batch 1254 (1000 rows)
# Saved batch 1255 (1000 rows)
# Saved batch 1256 (1000 rows)
# Saved batch 1257 (1000 rows)
# Saved batch 1258 (1000 rows)
# Saved batch 1259 (1000 rows)
# Saved batch 1260 (1000 rows)
# Saved batch 1261 (1000 rows)
# Saved batch 1262 (1000 rows)
# Saved batch 1263 (1000 rows)
# Saved batch 1264 (1000 rows)
# Saved batch 1265 (1000 rows)
# Saved batch 1266 (1000 rows)
# Saved batch 1267 (1000 rows)
# Saved batch 1268 (1000 rows)
# Saved batch 1269 (1000 rows)
# Saved batch 1270 (1000 rows)
# Saved batch 1271 (1000 rows)
# Saved batch 1272 (1000 rows)
# Saved batch 1273 (1000 rows)
# Saved batch 1274 (1000 rows)
# Saved batch 1275 (1000 rows)
# Saved batch 1276 (1000 rows)
# Saved batch 1277 (1000 rows)
# Saved batch 1278 (1000 rows)
# Saved batch 1279 (1000 rows)
# Saved batch 1280 (1000 rows)
# Saved batch 1281 (1000 rows)
# Saved batch 1282 (1000 rows)
# Saved batch 1283 (1000 rows)
# Saved batch 1284 (1000 rows)
# Saved batch 1285 (1000 rows)
# Saved batch 1286 (1000 rows)
# Saved batch 1287 (1000 rows)
# Saved batch 1288 (1000 rows)
# Saved batch 1289 (1000 rows)
# Saved batch 1290 (1000 rows)
# Saved batch 1291 (1000 rows)
# Saved batch 1292 (1000 rows)
# Saved batch 1293 (1000 rows)
# Saved batch 1294 (1000 rows)
# Saved batch 1295 (1000 rows)
# Saved batch 1296 (1000 rows)
# Saved batch 1297 (1000 rows)
# Saved batch 1298 (1000 rows)
# Saved batch 1299 (1000 rows)
# Saved batch 1300 (1000 rows)
# Saved batch 1301 (1000 rows)
# Saved batch 1302 (1000 rows)
# Saved batch 1303 (1000 rows)
# Saved batch 1304 (1000 rows)
# Saved batch 1305 (1000 rows)
# Saved batch 1306 (1000 rows)
# Saved batch 1307 (1000 rows)
# Saved batch 1308 (1000 rows)
# Saved batch 1309 (1000 rows)
# Saved batch 1310 (1000 rows)
# Saved batch 1311 (1000 rows)
# Saved batch 1312 (1000 rows)
# Saved batch 1313 (1000 rows)
# Saved batch 1314 (1000 rows)
# Saved batch 1315 (1000 rows)
# Saved batch 1316 (1000 rows)
# Saved batch 1317 (1000 rows)
# Saved batch 1318 (1000 rows)
# Saved batch 1319 (1000 rows)
# Saved batch 1320 (1000 rows)
# Saved batch 1321 (1000 rows)
# Saved batch 1322 (1000 rows)
# Saved batch 1323 (1000 rows)
# Saved batch 1324 (1000 rows)
# Saved batch 1325 (1000 rows)
# Saved batch 1326 (1000 rows)
# Saved batch 1327 (1000 rows)
# Saved batch 1328 (1000 rows)
# Saved batch 1329 (1000 rows)
# Saved batch 1330 (1000 rows)
# Saved batch 1331 (1000 rows)
# Saved batch 1332 (1000 rows)
# Saved batch 1333 (1000 rows)
# Saved batch 1334 (1000 rows)
# Saved batch 1335 (1000 rows)
# Saved batch 1336 (1000 rows)
# Saved batch 1337 (1000 rows)
# Saved batch 1338 (1000 rows)
# Saved batch 1339 (1000 rows)
# Saved batch 1340 (1000 rows)
# Saved batch 1341 (1000 rows)
# Saved batch 1342 (1000 rows)
# Saved batch 1343 (1000 rows)
# Saved batch 1344 (1000 rows)
# Saved batch 1345 (1000 rows)
# Saved batch 1346 (1000 rows)
# Saved batch 1347 (1000 rows)
# Saved batch 1348 (1000 rows)
# Saved batch 1349 (1000 rows)
# Saved batch 1350 (1000 rows)
# Saved batch 1351 (1000 rows)
# Saved batch 1352 (1000 rows)
# Saved batch 1353 (1000 rows)
# Saved batch 1354 (1000 rows)
# Saved batch 1355 (1000 rows)
# Saved batch 1356 (1000 rows)
# Saved batch 1357 (1000 rows)
# Saved batch 1358 (1000 rows)
# Saved batch 1359 (1000 rows)
# Saved batch 1360 (1000 rows)
# Saved batch 1361 (1000 rows)
# Saved batch 1362 (1000 rows)
# Saved batch 1363 (1000 rows)
# Saved batch 1364 (1000 rows)
# Saved batch 1365 (1000 rows)
# Saved batch 1366 (1000 rows)
# Saved batch 1367 (1000 rows)
# Saved batch 1368 (1000 rows)
# Saved batch 1369 (1000 rows)
# Saved batch 1370 (1000 rows)
# Saved batch 1371 (1000 rows)
# Saved batch 1372 (1000 rows)
# Saved batch 1373 (1000 rows)
# Saved batch 1374 (1000 rows)
# Saved batch 1375 (1000 rows)
# Saved batch 1376 (1000 rows)
# Saved batch 1377 (1000 rows)
# Saved batch 1378 (1000 rows)
# Saved batch 1379 (1000 rows)
# Saved batch 1380 (1000 rows)
# Saved batch 1381 (1000 rows)
# Saved batch 1382 (1000 rows)
# Saved batch 1383 (1000 rows)
# Saved batch 1384 (1000 rows)
# Saved batch 1385 (1000 rows)
# Saved batch 1386 (1000 rows)
# Saved batch 1387 (1000 rows)
# Saved batch 1388 (1000 rows)
# Saved batch 1389 (1000 rows)
# Saved batch 1390 (1000 rows)
# Saved batch 1391 (1000 rows)
# Saved batch 1392 (1000 rows)
# Saved batch 1393 (1000 rows)
# Saved batch 1394 (1000 rows)
# Saved batch 1395 (1000 rows)
# Saved batch 1396 (1000 rows)
# Saved batch 1397 (1000 rows)
# Saved batch 1398 (1000 rows)
# Saved batch 1399 (1000 rows)
# Saved batch 1400 (1000 rows)
# Saved batch 1401 (1000 rows)
# Saved batch 1402 (1000 rows)
# Saved batch 1403 (1000 rows)
# Saved batch 1404 (1000 rows)
# Saved batch 1405 (1000 rows)
# Saved batch 1406 (1000 rows)
# Saved batch 1407 (1000 rows)
# Saved batch 1408 (1000 rows)
# Saved batch 1409 (1000 rows)
# Saved batch 1410 (1000 rows)
# Saved batch 1411 (1000 rows)
# Saved batch 1412 (1000 rows)
# Saved batch 1413 (1000 rows)
# Saved batch 1414 (1000 rows)
# Saved batch 1415 (1000 rows)
# Saved batch 1416 (1000 rows)
# Saved batch 1417 (1000 rows)
# Saved batch 1418 (1000 rows)
# Saved batch 1419 (1000 rows)
# Saved batch 1420 (1000 rows)
# Saved batch 1421 (1000 rows)
# Saved batch 1422 (1000 rows)
# Saved batch 1423 (1000 rows)
# Saved batch 1424 (1000 rows)
# Saved batch 1425 (1000 rows)
# Saved batch 1426 (1000 rows)
# Saved batch 1427 (1000 rows)
# Saved batch 1428 (1000 rows)
# Saved batch 1429 (1000 rows)
# Saved batch 1430 (1000 rows)
# Saved batch 1431 (1000 rows)
# Saved batch 1432 (1000 rows)
# Saved batch 1433 (1000 rows)
# Saved batch 1434 (1000 rows)
# Saved batch 1435 (1000 rows)
# Saved batch 1436 (1000 rows)
# Saved batch 1437 (1000 rows)
# Saved batch 1438 (1000 rows)
# Saved batch 1439 (1000 rows)
# Saved batch 1440 (1000 rows)
# Saved batch 1441 (1000 rows)
# Saved batch 1442 (1000 rows)
# Saved batch 1443 (1000 rows)
# Saved batch 1444 (1000 rows)
# Saved batch 1445 (1000 rows)
# Saved batch 1446 (1000 rows)
# Saved batch 1447 (1000 rows)
# Saved batch 1448 (1000 rows)
# Saved batch 1449 (1000 rows)
# Saved batch 1450 (1000 rows)
# Saved batch 1451 (1000 rows)
# Saved batch 1452 (1000 rows)
# Saved batch 1453 (1000 rows)
# Saved batch 1454 (1000 rows)
# Saved batch 1455 (1000 rows)
# Saved batch 1456 (1000 rows)
# Saved batch 1457 (1000 rows)
# Saved batch 1458 (1000 rows)
# Saved batch 1459 (1000 rows)
# Saved batch 1460 (1000 rows)
# Saved batch 1461 (1000 rows)
# Saved batch 1462 (1000 rows)
# Saved batch 1463 (1000 rows)
# Saved batch 1464 (1000 rows)
# Saved batch 1465 (1000 rows)
# Saved batch 1466 (1000 rows)
# Saved batch 1467 (1000 rows)
# Saved batch 1468 (1000 rows)
# Saved batch 1469 (1000 rows)
# Saved batch 1470 (1000 rows)
# Saved batch 1471 (1000 rows)
# Saved batch 1472 (1000 rows)
# Saved batch 1473 (1000 rows)
# Saved batch 1474 (1000 rows)
# Saved batch 1475 (1000 rows)
# Saved batch 1476 (1000 rows)
# Saved batch 1477 (1000 rows)
# Saved batch 1478 (1000 rows)
# Saved batch 1479 (1000 rows)
# Saved batch 1480 (1000 rows)
# Saved batch 1481 (1000 rows)
# Saved batch 1482 (1000 rows)
# Saved batch 1483 (1000 rows)
# Saved batch 1484 (1000 rows)
# Saved batch 1485 (1000 rows)
# Saved batch 1486 (1000 rows)
# Saved batch 1487 (1000 rows)
# Saved batch 1488 (1000 rows)
# Saved batch 1489 (1000 rows)
# Saved batch 1490 (1000 rows)
# Saved batch 1491 (1000 rows)
# Saved batch 1492 (1000 rows)
# Saved batch 1493 (1000 rows)
# Saved batch 1494 (1000 rows)
# Saved batch 1495 (1000 rows)
# Saved batch 1496 (1000 rows)
# Saved batch 1497 (1000 rows)
# Saved batch 1498 (1000 rows)
# Saved batch 1499 (1000 rows)
# Saved batch 1500 (1000 rows)
# Saved batch 1501 (1000 rows)
# Saved batch 1502 (1000 rows)
# Saved batch 1503 (1000 rows)
# Saved batch 1504 (1000 rows)
# Saved batch 1505 (1000 rows)
# Saved batch 1506 (1000 rows)
# Saved batch 1507 (1000 rows)
# Saved batch 1508 (1000 rows)
# Saved batch 1509 (1000 rows)
# Saved batch 1510 (1000 rows)
# Saved batch 1511 (1000 rows)
# Saved batch 1512 (1000 rows)
# Saved batch 1513 (1000 rows)
# Saved batch 1514 (1000 rows)
# Saved batch 1515 (1000 rows)
# Saved batch 1516 (1000 rows)
# Saved batch 1517 (1000 rows)
# Saved batch 1518 (1000 rows)
# Saved batch 1519 (1000 rows)
# Saved batch 1520 (1000 rows)
# Saved batch 1521 (1000 rows)
# Saved batch 1522 (1000 rows)
# Saved batch 1523 (1000 rows)
# Saved batch 1524 (1000 rows)
# Saved batch 1525 (1000 rows)
# Saved batch 1526 (1000 rows)
# Saved batch 1527 (1000 rows)
# Saved batch 1528 (1000 rows)
# Saved batch 1529 (1000 rows)
# Saved batch 1530 (1000 rows)
# Saved batch 1531 (1000 rows)
# Saved batch 1532 (1000 rows)
# Saved batch 1533 (1000 rows)
# Saved batch 1534 (1000 rows)
# Saved batch 1535 (1000 rows)
# Saved batch 1536 (1000 rows)
# Saved batch 1537 (1000 rows)
# Saved batch 1538 (1000 rows)
# Saved batch 1539 (1000 rows)
# Saved batch 1540 (1000 rows)
# Saved batch 1541 (1000 rows)
# Saved batch 1542 (1000 rows)
# Saved batch 1543 (1000 rows)
# Saved batch 1544 (1000 rows)
# Saved batch 1545 (1000 rows)
# Saved batch 1546 (1000 rows)
# Saved batch 1547 (1000 rows)
# Saved batch 1548 (1000 rows)
# Saved batch 1549 (1000 rows)
# Saved batch 1550 (1000 rows)
# Saved batch 1551 (1000 rows)
# Saved batch 1552 (1000 rows)
# Saved batch 1553 (1000 rows)
# Saved batch 1554 (1000 rows)
# Saved batch 1555 (1000 rows)
# Saved batch 1556 (1000 rows)
# Saved batch 1557 (1000 rows)
# Saved batch 1558 (1000 rows)
# Saved batch 1559 (1000 rows)
# Saved batch 1560 (1000 rows)
# Saved batch 1561 (1000 rows)
# Saved batch 1562 (1000 rows)
# Saved batch 1563 (1000 rows)
# Saved batch 1564 (1000 rows)
# Saved batch 1565 (1000 rows)
# Saved batch 1566 (1000 rows)
# Saved batch 1567 (1000 rows)
# Saved batch 1568 (1000 rows)
# Saved batch 1569 (1000 rows)
# Saved batch 1570 (1000 rows)
# Saved batch 1571 (1000 rows)
# Saved batch 1572 (1000 rows)
# Saved batch 1573 (1000 rows)
# Saved batch 1574 (1000 rows)
# Saved batch 1575 (1000 rows)
# Saved batch 1576 (1000 rows)
# Saved batch 1577 (1000 rows)
# Saved batch 1578 (1000 rows)
# Saved batch 1579 (1000 rows)
# Saved batch 1580 (1000 rows)
# Saved batch 1581 (1000 rows)
# Saved batch 1582 (1000 rows)
# Saved batch 1583 (1000 rows)
# Saved batch 1584 (1000 rows)
# Saved batch 1585 (1000 rows)
# Saved batch 1586 (1000 rows)
# Saved batch 1587 (1000 rows)
# Saved batch 1588 (1000 rows)
# Saved batch 1589 (1000 rows)
# Saved batch 1590 (1000 rows)
# Saved batch 1591 (1000 rows)
# Saved batch 1592 (1000 rows)
# Saved batch 1593 (1000 rows)
# Saved batch 1594 (1000 rows)
# Saved batch 1595 (1000 rows)
# Saved batch 1596 (1000 rows)
# Saved batch 1597 (1000 rows)
# Saved batch 1598 (1000 rows)
# Saved batch 1599 (1000 rows)
# Saved batch 1600 (1000 rows)
# Saved batch 1601 (1000 rows)
# Saved batch 1602 (1000 rows)
# Saved batch 1603 (1000 rows)
# Saved batch 1604 (1000 rows)
# Saved batch 1605 (1000 rows)
# Saved batch 1606 (1000 rows)
# Saved batch 1607 (1000 rows)
# Saved batch 1608 (1000 rows)
# Saved batch 1609 (1000 rows)
# Saved batch 1610 (1000 rows)
# Saved batch 1611 (1000 rows)
# Saved batch 1612 (1000 rows)
# Saved batch 1613 (1000 rows)
# Saved batch 1614 (1000 rows)
# Saved batch 1615 (1000 rows)
# Saved batch 1616 (1000 rows)
# Saved batch 1617 (1000 rows)
# Saved batch 1618 (1000 rows)
# Saved batch 1619 (1000 rows)
# Saved batch 1620 (1000 rows)
# Saved batch 1621 (1000 rows)
# Saved batch 1622 (1000 rows)
# Saved batch 1623 (1000 rows)
# Saved batch 1624 (1000 rows)
# Saved batch 1625 (1000 rows)
# Saved batch 1626 (1000 rows)
# Saved batch 1627 (1000 rows)
# Saved batch 1628 (1000 rows)
# Saved batch 1629 (1000 rows)
# Saved batch 1630 (1000 rows)
# Saved batch 1631 (1000 rows)
# Saved batch 1632 (1000 rows)
# Saved batch 1633 (1000 rows)
# Saved batch 1634 (1000 rows)
# Saved batch 1635 (1000 rows)
# Saved batch 1636 (1000 rows)
# Saved batch 1637 (1000 rows)
# Saved batch 1638 (1000 rows)
# Saved batch 1639 (1000 rows)
# Saved batch 1640 (1000 rows)
# Saved batch 1641 (1000 rows)
# Saved batch 1642 (1000 rows)
# Saved batch 1643 (1000 rows)
# Saved batch 1644 (1000 rows)
# Saved batch 1645 (1000 rows)
# Saved batch 1646 (1000 rows)
# Saved batch 1647 (1000 rows)
# Saved batch 1648 (1000 rows)
# Saved batch 1649 (1000 rows)
# Saved batch 1650 (1000 rows)
# Saved batch 1651 (1000 rows)
# Saved batch 1652 (1000 rows)
# Saved batch 1653 (1000 rows)
# Saved batch 1654 (1000 rows)
# Saved batch 1655 (1000 rows)
# Saved batch 1656 (1000 rows)
# Saved batch 1657 (1000 rows)
# Saved batch 1658 (1000 rows)
# Saved batch 1659 (1000 rows)
# Saved batch 1660 (1000 rows)
# Saved batch 1661 (1000 rows)
# Saved batch 1662 (1000 rows)
# Saved batch 1663 (1000 rows)
# Saved batch 1664 (1000 rows)
# ...
# Saved batch 2663 (1000 rows)
# Saved batch 2664 (1000 rows)
# Saved batch 2665 (1000 rows)
# Saved batch 2666 (1000 rows)
# Saved batch 2667 (1000 rows)
# Saved batch 2668 (1000 rows)
# Saved batch 2669 (1000 rows)
# Saved batch 2670 (1000 rows)
# Saved batch 2671 (1000 rows)
# Saved batch 2672 (1000 rows)
# Saved batch 2673 (1000 rows)
# Saved batch 2674 (1000 rows)
# Saved batch 2675 (1000 rows)
# Saved batch 2676 (1000 rows)
# Saved batch 2677 (1000 rows)
# Saved batch 2678 (1000 rows)
# Saved batch 2679 (1000 rows)
# Saved batch 2680 (1000 rows)
# Saved batch 2681 (1000 rows)
# Saved batch 2682 (1000 rows)
# Saved batch 2683 (1000 rows)
# Saved batch 2684 (1000 rows)
# Saved batch 2685 (1000 rows)
# Saved batch 2686 (1000 rows)
# Saved batch 2687 (1000 rows)
# Saved batch 2688 (1000 rows)
# Saved batch 2689 (1000 rows)
# Saved batch 2690 (1000 rows)
# Saved batch 2691 (1000 rows)
# Saved batch 2692 (1000 rows)
# Saved batch 2693 (1000 rows)
# Saved batch 2694 (1000 rows)
# Saved batch 2695 (1000 rows)
# Saved batch 2696 (1000 rows)
# Saved batch 2697 (1000 rows)
# Saved batch 2698 (1000 rows)
# Saved batch 2699 (1000 rows)
# Saved batch 2700 (1000 rows)
# Saved batch 2701 (1000 rows)
# Saved batch 2702 (1000 rows)
# Saved batch 2703 (1000 rows)
# Saved batch 2704 (1000 rows)
# Saved batch 2705 (1000 rows)
# Saved batch 2706 (1000 rows)
# Saved batch 2707 (1000 rows)
# Saved batch 2708 (1000 rows)
# Saved batch 2709 (1000 rows)
# Saved batch 2710 (1000 rows)
# Saved batch 2711 (1000 rows)
# Saved batch 2712 (1000 rows)
# Saved batch 2713 (1000 rows)
# Saved batch 2714 (1000 rows)
# Saved batch 2715 (1000 rows)
# Saved batch 2716 (1000 rows)
# Saved batch 2717 (1000 rows)
# Saved batch 2718 (1000 rows)
# Saved batch 2719 (1000 rows)
# Saved batch 2720 (1000 rows)
# Saved batch 2721 (1000 rows)
# Saved batch 2722 (1000 rows)
# Saved batch 2723 (1000 rows)
# Saved batch 2724 (1000 rows)
# Saved batch 2725 (1000 rows)
# Saved batch 2726 (1000 rows)
# Saved batch 2727 (1000 rows)
# Saved batch 2728 (1000 rows)
# Saved batch 2729 (1000 rows)
# Saved batch 2730 (1000 rows)
# Saved batch 2731 (1000 rows)
# Saved batch 2732 (1000 rows)
# Saved batch 2733 (1000 rows)
# Saved batch 2734 (1000 rows)
# Saved batch 2735 (1000 rows)
# Saved batch 2736 (1000 rows)
# Saved batch 2737 (1000 rows)
# Saved batch 2738 (1000 rows)
# Saved batch 2739 (1000 rows)
# Saved batch 2740 (1000 rows)
# Saved batch 2741 (1000 rows)
# Saved batch 2742 (1000 rows)
# Saved batch 2743 (1000 rows)
# Saved batch 2744 (1000 rows)
# Saved batch 2745 (1000 rows)
# Saved batch 2746 (1000 rows)
# Saved batch 2747 (1000 rows)
# Saved batch 2748 (1000 rows)
# Saved batch 2749 (1000 rows)
# Saved batch 2750 (1000 rows)
# Saved batch 2751 (1000 rows)
# Saved batch 2752 (1000 rows)
# Saved batch 2753 (1000 rows)
# Saved batch 2754 (1000 rows)
# Saved batch 2755 (1000 rows)
# Saved batch 2756 (1000 rows)
# Saved batch 2757 (1000 rows)
# Saved batch 2758 (1000 rows)
# Saved batch 2759 (1000 rows)
# Saved batch 2760 (1000 rows)
# Saved batch 2761 (1000 rows)
# Saved batch 2762 (1000 rows)
# Saved batch 2763 (1000 rows)
# Saved batch 2764 (1000 rows)
# Saved batch 2765 (1000 rows)
# Saved batch 2766 (1000 rows)
# Saved batch 2767 (1000 rows)
# Saved batch 2768 (1000 rows)
# Saved batch 2769 (1000 rows)
# Saved batch 2770 (1000 rows)
# Saved batch 2771 (1000 rows)
# Saved batch 2772 (1000 rows)
# Saved batch 2773 (1000 rows)
# Saved batch 2774 (1000 rows)
# Saved batch 2775 (1000 rows)
# Saved batch 2776 (1000 rows)
# Saved batch 2777 (1000 rows)
# Saved batch 2778 (1000 rows)
# Saved batch 2779 (1000 rows)
# Saved batch 2780 (1000 rows)
# Saved batch 2781 (1000 rows)
# Saved batch 2782 (1000 rows)
# Saved batch 2783 (1000 rows)
# Saved batch 2784 (1000 rows)
# Saved batch 2785 (1000 rows)
# Saved batch 2786 (1000 rows)
# Saved batch 2787 (1000 rows)
# Saved batch 2788 (1000 rows)
# Saved batch 2789 (1000 rows)
# Saved batch 2790 (1000 rows)
# Saved batch 2791 (1000 rows)
# Saved batch 2792 (1000 rows)
# Saved batch 2793 (1000 rows)
# Saved batch 2794 (1000 rows)
# Saved batch 2795 (1000 rows)
# Saved batch 2796 (1000 rows)
# Saved batch 2797 (1000 rows)
# Saved batch 2798 (1000 rows)
# Saved batch 2799 (1000 rows)
# Saved batch 2800 (1000 rows)
# Saved batch 2801 (1000 rows)
# Saved batch 2802 (1000 rows)
# Saved batch 2803 (1000 rows)
# Saved batch 2804 (1000 rows)
# Saved batch 2805 (1000 rows)
# Saved batch 2806 (1000 rows)
# Saved batch 2807 (1000 rows)
# Saved batch 2808 (1000 rows)
# Saved batch 2809 (1000 rows)
# Saved batch 2810 (1000 rows)
# Saved batch 2811 (1000 rows)
# Saved batch 2812 (1000 rows)
# Saved batch 2813 (1000 rows)
# Saved batch 2814 (1000 rows)
# Saved batch 2815 (1000 rows)
# Saved batch 2816 (1000 rows)
# Saved batch 2817 (1000 rows)
# Saved batch 2818 (1000 rows)
# Saved batch 2819 (1000 rows)
# Saved batch 2820 (1000 rows)
# Saved batch 2821 (1000 rows)
# Saved batch 2822 (1000 rows)
# Saved batch 2823 (1000 rows)
# Saved batch 2824 (1000 rows)
# Saved batch 2825 (1000 rows)
# Saved batch 2826 (1000 rows)
# Saved batch 2827 (1000 rows)
# Saved batch 2828 (1000 rows)
# Saved batch 2829 (1000 rows)
# Saved batch 2830 (1000 rows)
# Saved batch 2831 (1000 rows)
# Saved batch 2832 (1000 rows)
# Saved batch 2833 (1000 rows)
# Saved batch 2834 (1000 rows)
# Saved batch 2835 (1000 rows)
# Saved batch 2836 (1000 rows)
# Saved batch 2837 (1000 rows)
# Saved batch 2838 (1000 rows)
# Saved batch 2839 (1000 rows)
# Saved batch 2840 (1000 rows)
# Saved batch 2841 (1000 rows)
# Saved batch 2842 (1000 rows)
# Saved batch 2843 (1000 rows)
# Saved batch 2844 (1000 rows)
# Saved batch 2845 (1000 rows)
# Saved batch 2846 (1000 rows)
# Saved batch 2847 (1000 rows)
# Saved batch 2848 (1000 rows)
# Saved batch 2849 (1000 rows)
# Saved batch 2850 (1000 rows)
# Saved batch 2851 (1000 rows)
# Saved batch 2852 (1000 rows)
# Saved batch 2853 (1000 rows)
# Saved batch 2854 (1000 rows)
# Saved batch 2855 (1000 rows)
# Saved batch 2856 (1000 rows)
# Saved batch 2857 (1000 rows)
# Saved batch 2858 (1000 rows)
# Saved batch 2859 (1000 rows)
# Saved batch 2860 (1000 rows)
# Saved batch 2861 (1000 rows)
# Saved batch 2862 (1000 rows)
# Saved batch 2863 (1000 rows)
# Saved batch 2864 (1000 rows)
# Saved batch 2865 (1000 rows)
# Saved batch 2866 (1000 rows)
# Saved batch 2867 (1000 rows)
# Saved batch 2868 (1000 rows)
# Saved batch 2869 (1000 rows)
# Saved batch 2870 (1000 rows)
# Saved batch 2871 (1000 rows)
# Saved batch 2872 (1000 rows)
# Saved batch 2873 (1000 rows)
# Saved batch 2874 (1000 rows)
# Saved batch 2875 (1000 rows)
# Saved batch 2876 (1000 rows)
# Saved batch 2877 (1000 rows)
# Saved batch 2878 (1000 rows)
# Saved batch 2879 (1000 rows)
# Saved batch 2880 (1000 rows)
# Saved batch 2881 (1000 rows)
# Saved batch 2882 (1000 rows)
# Saved batch 2883 (1000 rows)
# Saved batch 2884 (1000 rows)
# Saved batch 2885 (1000 rows)
# Saved batch 2886 (1000 rows)
# Saved batch 2887 (1000 rows)
# Saved batch 2888 (1000 rows)
# Saved batch 2889 (1000 rows)
# Saved batch 2890 (1000 rows)
# Saved batch 2891 (1000 rows)
# Saved batch 2892 (1000 rows)
# Saved batch 2893 (1000 rows)
# Saved batch 2894 (1000 rows)
# Saved batch 2895 (1000 rows)
# Saved batch 2896 (1000 rows)
# Saved batch 2897 (1000 rows)
# Saved batch 2898 (1000 rows)
# Saved batch 2899 (1000 rows)
# Saved batch 2900 (1000 rows)
# Saved batch 2901 (1000 rows)
# Saved batch 2902 (1000 rows)
# Saved batch 2903 (1000 rows)
# Saved batch 2904 (1000 rows)
# Saved batch 2905 (1000 rows)
# Saved batch 2906 (1000 rows)
# Saved batch 2907 (1000 rows)
# Saved batch 2908 (1000 rows)
# Saved batch 2909 (1000 rows)
# Saved batch 2910 (1000 rows)
# Saved batch 2911 (1000 rows)
# Saved batch 2912 (1000 rows)
# Saved batch 2913 (1000 rows)
# Saved batch 2914 (1000 rows)
# Saved batch 2915 (1000 rows)
# Saved batch 2916 (1000 rows)
# Saved batch 2917 (1000 rows)
# Saved batch 2918 (1000 rows)
# Saved batch 2919 (1000 rows)
# Saved batch 2920 (1000 rows)
# Saved batch 2921 (1000 rows)
# Saved batch 2922 (1000 rows)
# Saved batch 2923 (1000 rows)
# Saved batch 2924 (1000 rows)
# Saved batch 2925 (1000 rows)
# Saved batch 2926 (1000 rows)
# Saved batch 2927 (1000 rows)
# Saved batch 2928 (1000 rows)
# Saved batch 2929 (1000 rows)
# Saved batch 2930 (1000 rows)
# Saved batch 2931 (1000 rows)
# Saved batch 2932 (1000 rows)
# Saved batch 2933 (1000 rows)
# Saved batch 2934 (1000 rows)
# Saved batch 2935 (1000 rows)
# Saved batch 2936 (1000 rows)
# Saved batch 2937 (1000 rows)
# Saved batch 2938 (1000 rows)
# Saved batch 2939 (1000 rows)
# Saved batch 2940 (1000 rows)
# Saved batch 2941 (1000 rows)
# Saved batch 2942 (1000 rows)
# Saved batch 2943 (1000 rows)
# Saved batch 2944 (1000 rows)
# Saved batch 2945 (1000 rows)
# Saved batch 2946 (1000 rows)
# Saved batch 2947 (1000 rows)
# Saved batch 2948 (1000 rows)
# Saved batch 2949 (1000 rows)
# Saved batch 2950 (1000 rows)
# Saved batch 2951 (1000 rows)
# Saved batch 2952 (1000 rows)
# Saved batch 2953 (1000 rows)
# Saved batch 2954 (1000 rows)
# Saved batch 2955 (1000 rows)
# Saved batch 2956 (1000 rows)
# Saved batch 2957 (1000 rows)
# Saved batch 2958 (1000 rows)
# Saved batch 2959 (1000 rows)
# Saved batch 2960 (1000 rows)
# Saved batch 2961 (1000 rows)
# Saved batch 2962 (1000 rows)
# Saved batch 2963 (1000 rows)
# Saved batch 2964 (1000 rows)
# Saved batch 2965 (1000 rows)
# Saved batch 2966 (1000 rows)
# Saved batch 2967 (1000 rows)
# Saved batch 2968 (1000 rows)
# Saved batch 2969 (1000 rows)
# Saved batch 2970 (1000 rows)
# Saved batch 2971 (1000 rows)
# Saved batch 2972 (1000 rows)
# Saved batch 2973 (1000 rows)
# Saved batch 2974 (1000 rows)
# Saved batch 2975 (1000 rows)
# Saved batch 2976 (1000 rows)
# Saved batch 2977 (1000 rows)
# Saved batch 2978 (1000 rows)
# Saved batch 2979 (1000 rows)
# Saved batch 2980 (1000 rows)
# Saved batch 2981 (1000 rows)
# Saved batch 2982 (1000 rows)
# Saved batch 2983 (1000 rows)
# Saved batch 2984 (1000 rows)
# Saved batch 2985 (1000 rows)
# Saved batch 2986 (1000 rows)
# Saved batch 2987 (1000 rows)
# Saved batch 2988 (1000 rows)
# Saved batch 2989 (1000 rows)
# Saved batch 2990 (1000 rows)
# Saved batch 2991 (1000 rows)
# Saved batch 2992 (1000 rows)
# Saved batch 2993 (1000 rows)
# Saved batch 2994 (1000 rows)
# Saved batch 2995 (1000 rows)
# Saved batch 2996 (1000 rows)
# Saved batch 2997 (1000 rows)
# Saved batch 2998 (1000 rows)
# Saved batch 2999 (1000 rows)
# Saved batch 3000 (1000 rows)
# Saved batch 3001 (1000 rows)
# Saved batch 3002 (1000 rows)
# Saved batch 3003 (1000 rows)
# Saved batch 3004 (1000 rows)
# Saved batch 3005 (1000 rows)
# Saved batch 3006 (1000 rows)
# Saved batch 3007 (1000 rows)
# Saved batch 3008 (1000 rows)
# Saved batch 3009 (1000 rows)
# Saved batch 3010 (1000 rows)
# Saved batch 3011 (1000 rows)
# Saved batch 3012 (1000 rows)
# Saved batch 3013 (1000 rows)
# Saved batch 3014 (1000 rows)
# Saved batch 3015 (1000 rows)
# Saved batch 3016 (1000 rows)
# Saved batch 3017 (1000 rows)
# Saved batch 3018 (1000 rows)
# Saved batch 3019 (1000 rows)
# Saved batch 3020 (1000 rows)
# Saved batch 3021 (1000 rows)
# Saved batch 3022 (1000 rows)
# Saved batch 3023 (1000 rows)
# Saved batch 3024 (1000 rows)
# Saved batch 3025 (1000 rows)
# Saved batch 3026 (1000 rows)
# Saved batch 3027 (1000 rows)
# Saved batch 3028 (1000 rows)
# Saved batch 3029 (1000 rows)
# Saved batch 3030 (1000 rows)
# Saved batch 3031 (1000 rows)
# Saved batch 3032 (1000 rows)
# Saved batch 3033 (1000 rows)
# Saved batch 3034 (1000 rows)
# Saved batch 3035 (1000 rows)
# Saved batch 3036 (1000 rows)
# Saved batch 3037 (1000 rows)
# Saved batch 3038 (1000 rows)
# Saved batch 3039 (1000 rows)
# Saved batch 3040 (1000 rows)
# Saved batch 3041 (1000 rows)
# Saved batch 3042 (1000 rows)
# Saved batch 3043 (1000 rows)
# Saved batch 3044 (1000 rows)
# Saved batch 3045 (1000 rows)
# Saved batch 3046 (1000 rows)
# Saved batch 3047 (1000 rows)
# Saved batch 3048 (1000 rows)
# Saved batch 3049 (1000 rows)
# Saved batch 3050 (1000 rows)
# Saved batch 3051 (1000 rows)
# Saved batch 3052 (1000 rows)
# Saved batch 3053 (1000 rows)
# Saved batch 3054 (1000 rows)
# Saved batch 3055 (1000 rows)
# Saved batch 3056 (1000 rows)
# Saved batch 3057 (1000 rows)
# Saved batch 3058 (1000 rows)
# Saved batch 3059 (1000 rows)
# Saved batch 3060 (1000 rows)
# Saved batch 3061 (1000 rows)
# Saved batch 3062 (1000 rows)
# Saved batch 3063 (1000 rows)
# Saved batch 3064 (1000 rows)
# Saved batch 3065 (1000 rows)
# Saved batch 3066 (1000 rows)
# Saved batch 3067 (1000 rows)
# Saved batch 3068 (1000 rows)
# Saved batch 3069 (1000 rows)
# Saved batch 3070 (1000 rows)
# Saved batch 3071 (1000 rows)
# Saved batch 3072 (1000 rows)
# Saved batch 3073 (1000 rows)
# Saved batch 3074 (1000 rows)
# Saved batch 3075 (1000 rows)
# Saved batch 3076 (1000 rows)
# Saved batch 3077 (1000 rows)
# Saved batch 3078 (1000 rows)
# Saved batch 3079 (1000 rows)
# Saved batch 3080 (1000 rows)
# Saved batch 3081 (1000 rows)
# Saved batch 3082 (1000 rows)
# Saved batch 3083 (1000 rows)
# Saved batch 3084 (1000 rows)
# Saved batch 3085 (1000 rows)
# Saved batch 3086 (1000 rows)
# Saved batch 3087 (1000 rows)
# Saved batch 3088 (1000 rows)
# Saved batch 3089 (1000 rows)
# Saved batch 3090 (1000 rows)
# Saved batch 3091 (1000 rows)
# Saved batch 3092 (1000 rows)
# Saved batch 3093 (1000 rows)
# Saved batch 3094 (1000 rows)
# Saved batch 3095 (1000 rows)
# Saved batch 3096 (1000 rows)
# Saved batch 3097 (1000 rows)
# Saved batch 3098 (1000 rows)
# Saved batch 3099 (1000 rows)
# Saved batch 3100 (1000 rows)
# Saved batch 3101 (1000 rows)
# Saved batch 3102 (1000 rows)
# Saved batch 3103 (1000 rows)
# Saved batch 3104 (1000 rows)
# Saved batch 3105 (1000 rows)
# Saved batch 3106 (1000 rows)
# Saved batch 3107 (1000 rows)
# Saved batch 3108 (1000 rows)
# Saved batch 3109 (1000 rows)
# Saved batch 3110 (1000 rows)
# Saved batch 3111 (1000 rows)
# Saved batch 3112 (1000 rows)
# Saved batch 3113 (1000 rows)
# Saved batch 3114 (1000 rows)
# Saved batch 3115 (1000 rows)
# Saved batch 3116 (1000 rows)
# Saved batch 3117 (1000 rows)
# Saved batch 3118 (1000 rows)
# Saved batch 3119 (1000 rows)
# Saved batch 3120 (1000 rows)
# Saved batch 3121 (1000 rows)
# Saved batch 3122 (1000 rows)
# Saved batch 3123 (1000 rows)
# Saved batch 3124 (1000 rows)
# Saved batch 3125 (1000 rows)
# Saved batch 3126 (1000 rows)
# Saved batch 3127 (1000 rows)
# Saved batch 3128 (1000 rows)
# Saved batch 3129 (1000 rows)
# Saved batch 3130 (1000 rows)
# Saved batch 3131 (1000 rows)
# Saved batch 3132 (1000 rows)
# Saved batch 3133 (1000 rows)
# Saved batch 3134 (1000 rows)
# Saved batch 3135 (1000 rows)
# Saved batch 3136 (1000 rows)
# Saved batch 3137 (1000 rows)
# Saved batch 3138 (1000 rows)
# Saved batch 3139 (1000 rows)
# Saved batch 3140 (1000 rows)
# Saved batch 3141 (1000 rows)
# Saved batch 3142 (1000 rows)
# Saved batch 3143 (1000 rows)
# Saved batch 3144 (1000 rows)
# Saved batch 3145 (1000 rows)
# Saved batch 3146 (1000 rows)
# Saved batch 3147 (1000 rows)
# Saved batch 3148 (1000 rows)
# Saved batch 3149 (1000 rows)
# Saved batch 3150 (1000 rows)
# Saved batch 3151 (1000 rows)
# Saved batch 3152 (1000 rows)
# Saved batch 3153 (1000 rows)
# Saved batch 3154 (1000 rows)
# Saved batch 3155 (1000 rows)
# Saved batch 3156 (1000 rows)
# Saved batch 3157 (1000 rows)
# Saved batch 3158 (1000 rows)
# Saved batch 3159 (1000 rows)
# Saved batch 3160 (1000 rows)
# Saved batch 3161 (1000 rows)
# Saved batch 3162 (1000 rows)
# Saved batch 3163 (1000 rows)
# Saved batch 3164 (1000 rows)
# Saved batch 3165 (1000 rows)
# Saved batch 3166 (1000 rows)
# Saved batch 3167 (1000 rows)
# Saved batch 3168 (1000 rows)
# Saved batch 3169 (1000 rows)
# Saved batch 3170 (1000 rows)
# Saved batch 3171 (1000 rows)
# Saved batch 3172 (1000 rows)
# Saved batch 3173 (1000 rows)
# Saved batch 3174 (1000 rows)
# Saved batch 3175 (1000 rows)
# Saved batch 3176 (1000 rows)
# Saved batch 3177 (1000 rows)
# Saved batch 3178 (1000 rows)
# Saved batch 3179 (1000 rows)
# Saved batch 3180 (1000 rows)
# Saved batch 3181 (1000 rows)
# Saved batch 3182 (1000 rows)
# Saved batch 3183 (1000 rows)
# Saved batch 3184 (1000 rows)
# Saved batch 3185 (1000 rows)
# Saved batch 3186 (1000 rows)
# Saved batch 3187 (1000 rows)
# Saved batch 3188 (1000 rows)
# Saved batch 3189 (1000 rows)
# Saved batch 3190 (1000 rows)
# Saved batch 3191 (1000 rows)
# Saved batch 3192 (1000 rows)
# Saved batch 3193 (1000 rows)
# Saved batch 3194 (1000 rows)
# Saved final batch 3195 (28 rows)
# Temp folder removed: C:\Users\maian\OneDrive - The University of the West Indies, St. Augustine\Desktop\big_data_a3\output_folder\temp_extract\Musical_Instruments
# Loaded 2984 files into Dask DataFrame
# Loaded 213 files into Dask DataFrame
# Reading parquet files as Dask DataFrames
# Merging review and meta on 'parent_asin'
# Filtering bad data
# Extracting brand
# Computing derived columns
# Selecting necessary columns
# Done! File cleaned.
# ✅ Persisted in 0.00 seconds
# [                                        ] | 0% Completed | 143.46 ss

# %%
import dask.dataframe as dd
import matplotlib.pyplot as plt

full_df = dd.read_parquet("cleaned_data/*.parquet")

# Rating distribution
rating_counts = full_df["rating"].value_counts().compute().sort_index()
rating_counts.plot(kind="bar", title="Star Rating Distribution")
plt.xlabel("Star Rating")
plt.ylabel("Count")
plt.show()

# Top 10 categories
if "main_category" in full_df.columns:
    top_categories = full_df["main_category"].value_counts().nlargest(10).compute()
    top_categories.plot(kind="bar", title="Top 10 Categories by Review Count")

# Top 10 brands (excluding Unknown)
top_brands = full_df[full_df["brand"] != "Unknown"]["brand"].value_counts().nlargest(10).compute()
top_brands.plot(kind="bar", title="Top 10 Brands")

# Rating trend over time
if "year" in full_df.columns:
    avg_by_year = full_df.groupby("year")["rating"].mean().compute()
    avg_by_year.plot(marker="o", title="Average Star Rating by Year")

# Correlation: review length vs rating
if "review_length" in full_df.columns:
    correlation = full_df[["review_length", "rating"]].corr().compute()
    print("Correlation matrix:\n", correlation)
